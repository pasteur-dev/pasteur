# %% [markdown]
# # Single Table Analysis Template

# %%
# Removes lint errors from VS Code
from typing import Dict, TYPE_CHECKING, Tuple, List

if TYPE_CHECKING:
    import kedro

    catalog: kedro.io.data_catalog.DataCatalog
    session: kedro.framework.session.session.KedroSession
    pipelines: Dict[str, kedro.pipeline.pipeline.Pipeline]

# %%
import os

VIEW = os.getenv("DATASET_VIEW") or "tab_adult"
TABLE = os.getenv("DATASET_TABLE") or "table"
ALG = os.getenv("SYNTH_ALG") or "privbayes"

import numpy as np
import pandas as pd
from pasteur.transform.table import TableTransformer

wrk: pd.DataFrame = catalog.load(f"{VIEW}.wrk.idx_{TABLE}")
alg: pd.DataFrame = catalog.load(f"{VIEW}.{ALG}.idx_{TABLE}")
tst: pd.DataFrame = catalog.load(f"{VIEW}.tst.idx_{TABLE}")

trn: TableTransformer = catalog.load(f"{VIEW}.wrk.trn_{TABLE}")

from pasteur.metadata import Metadata
params = catalog.load(f"parameters")
meta = Metadata.from_kedro_params(params, VIEW, {TABLE: wrk}).get_table(TABLE)

random_state = catalog.load("params:random_state")

# %%
cols = list(wrk.keys())

a = wrk[cols].to_numpy(dtype="uint16")
b = alg[cols].to_numpy(dtype="uint16")
c = tst[cols].to_numpy(dtype="uint16")

domain = np.concatenate([a, b, c]).max(axis=0) + 1

# %%
from pasteur.synth.privbayes import calc_marginal_1way

# Add at least one sample prob to distr chisquare valid
zero_fill = 1/len(a)

def marg(s: np.ndarray, names: list[str]):
    x = [cols.index(name) for name in names]
    return calc_marginal_1way(s, domain, x, True, zero_fill)

# %%
from scipy.stats import chisquare

res = []
for col in cols:
    k = marg(a, [col])
    j = marg(c, [col])
    chi, p = chisquare(k, j)
    # print(f"{name:12}.{col:20}: X^2={chi:3.3f} p={100*p:7.3f}%")
    res.append([col, chi, p])

res = pd.DataFrame(res, columns=["col", "X^2", "p"])
res.set_index(keys=["col"]).sort_index().style.background_gradient(axis=0)
# Out:
# <pandas.io.formats.style.Styler object at 0x7fde3fb8e5f0>
# <style type="text/css">
# #T_00000_row0_col0 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_00000_row0_col1, #T_00000_row1_col1, #T_00000_row2_col1, #T_00000_row3_col1, #T_00000_row4_col1, #T_00000_row5_col1, #T_00000_row6_col1, #T_00000_row8_col1, #T_00000_row9_col0, #T_00000_row9_col1, #T_00000_row10_col1, #T_00000_row11_col1, #T_00000_row12_col1, #T_00000_row14_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_00000_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_00000_row2_col0 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_00000_row3_col0, #T_00000_row4_col0 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_00000_row5_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_00000_row6_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_00000_row7_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_00000_row7_col1, #T_00000_row13_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_00000_row8_col0 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_00000_row10_col0 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_00000_row11_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_00000_row12_col0 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_00000_row13_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_00000_row14_col0 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_00000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00000_level0_col0" class="col_heading level0 col0" >X^2</th>
#       <th id="T_00000_level0_col1" class="col_heading level0 col1" >p</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00000_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_00000_row0_col0" class="data row0 col0" >0.001818</td>
#       <td id="T_00000_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row1" class="row_heading level0 row1" >capital-gain</th>
#       <td id="T_00000_row1_col0" class="data row1 col0" >0.000749</td>
#       <td id="T_00000_row1_col1" class="data row1 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row2" class="row_heading level0 row2" >capital-loss</th>
#       <td id="T_00000_row2_col0" class="data row2 col0" >0.001481</td>
#       <td id="T_00000_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_00000_row3_col0" class="data row3 col0" >0.001140</td>
#       <td id="T_00000_row3_col1" class="data row3 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row4" class="row_heading level0 row4" >education-num</th>
#       <td id="T_00000_row4_col0" class="data row4 col0" >0.001140</td>
#       <td id="T_00000_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row5" class="row_heading level0 row5" >fnlwgt</th>
#       <td id="T_00000_row5_col0" class="data row5 col0" >0.002013</td>
#       <td id="T_00000_row5_col1" class="data row5 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row6" class="row_heading level0 row6" >hours-per-week</th>
#       <td id="T_00000_row6_col0" class="data row6 col0" >0.003205</td>
#       <td id="T_00000_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row7" class="row_heading level0 row7" >income</th>
#       <td id="T_00000_row7_col0" class="data row7 col0" >0.000095</td>
#       <td id="T_00000_row7_col1" class="data row7 col1" >0.992243</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row8" class="row_heading level0 row8" >marital-status</th>
#       <td id="T_00000_row8_col0" class="data row8 col0" >0.000498</td>
#       <td id="T_00000_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row9" class="row_heading level0 row9" >native-country</th>
#       <td id="T_00000_row9_col0" class="data row9 col0" >0.003623</td>
#       <td id="T_00000_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row10" class="row_heading level0 row10" >occupation</th>
#       <td id="T_00000_row10_col0" class="data row10 col0" >0.002237</td>
#       <td id="T_00000_row10_col1" class="data row10 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row11" class="row_heading level0 row11" >race</th>
#       <td id="T_00000_row11_col0" class="data row11 col0" >0.000173</td>
#       <td id="T_00000_row11_col1" class="data row11 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row12" class="row_heading level0 row12" >relationship</th>
#       <td id="T_00000_row12_col0" class="data row12 col0" >0.000427</td>
#       <td id="T_00000_row12_col1" class="data row12 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row13" class="row_heading level0 row13" >sex</th>
#       <td id="T_00000_row13_col0" class="data row13 col0" >0.000025</td>
#       <td id="T_00000_row13_col1" class="data row13 col1" >0.996045</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row14" class="row_heading level0 row14" >workclass</th>
#       <td id="T_00000_row14_col0" class="data row14 col0" >0.000878</td>
#       <td id="T_00000_row14_col1" class="data row14 col1" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from scipy.special import rel_entr

res = []
for col_i in cols:
    for col_j in cols:
        k = marg(a, [col_i, col_j])
        j = marg(c, [col_i, col_j])
        
        kl = rel_entr(k, j).sum()
        kl_norm = 1 / (1 + kl)
        res.append([col_i, col_j, kl, kl_norm, len(k)])

res = pd.DataFrame(
    res,
    columns=[
        "col_i",
        "col_j",
        "kl",
        "kl_norm",
        "mlen",
    ],
)
res.head().style
# Out:
# <pandas.io.formats.style.Styler object at 0x7fde411bfbb0>
# <style type="text/css">
# </style>
# <table id="T_00000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00000_level0_col0" class="col_heading level0 col0" >col_i</th>
#       <th id="T_00000_level0_col1" class="col_heading level0 col1" >col_j</th>
#       <th id="T_00000_level0_col2" class="col_heading level0 col2" >kl</th>
#       <th id="T_00000_level0_col3" class="col_heading level0 col3" >kl_norm</th>
#       <th id="T_00000_level0_col4" class="col_heading level0 col4" >mlen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00000_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00000_row0_col0" class="data row0 col0" >age</td>
#       <td id="T_00000_row0_col1" class="data row0 col1" >age</td>
#       <td id="T_00000_row0_col2" class="data row0 col2" >0.000909</td>
#       <td id="T_00000_row0_col3" class="data row0 col3" >0.999092</td>
#       <td id="T_00000_row0_col4" class="data row0 col4" >1089</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00000_row1_col0" class="data row1 col0" >age</td>
#       <td id="T_00000_row1_col1" class="data row1 col1" >workclass</td>
#       <td id="T_00000_row1_col2" class="data row1 col2" >0.009549</td>
#       <td id="T_00000_row1_col3" class="data row1 col3" >0.990542</td>
#       <td id="T_00000_row1_col4" class="data row1 col4" >297</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00000_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_00000_row2_col1" class="data row2 col1" >fnlwgt</td>
#       <td id="T_00000_row2_col2" class="data row2 col2" >0.017001</td>
#       <td id="T_00000_row2_col3" class="data row2 col3" >0.983283</td>
#       <td id="T_00000_row2_col4" class="data row2 col4" >1089</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00000_row3_col0" class="data row3 col0" >age</td>
#       <td id="T_00000_row3_col1" class="data row3 col1" >education</td>
#       <td id="T_00000_row3_col2" class="data row3 col2" >0.018385</td>
#       <td id="T_00000_row3_col3" class="data row3 col3" >0.981947</td>
#       <td id="T_00000_row3_col4" class="data row3 col4" >528</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00000_row4_col0" class="data row4 col0" >age</td>
#       <td id="T_00000_row4_col1" class="data row4 col1" >education-num</td>
#       <td id="T_00000_row4_col2" class="data row4 col2" >0.018385</td>
#       <td id="T_00000_row4_col3" class="data row4 col3" >0.981947</td>
#       <td id="T_00000_row4_col4" class="data row4 col4" >528</td>
#     </tr>
#   </tbody>
# </table>

# %%
def mk_kl_plot(filter=None, val="kl_norm"):
    pt = res[filter] if filter is not None else res
    pt = pt.pivot_table(
        values=val, index=["col_i"], columns=["col_j"]
    )

    # Try to tweak colormap
    vmin = vmax = None
    # match val:
    #     case "kl_norm":
    #         vmin = 0.996
    #     case "kl":
    #         vmax = 0.04
    #     case "mlen":
    #         vmax = 100

    # pt = pt.reindex(index=idx, columns=cols)
    pt = pt.style.background_gradient(axis=None, vmin=vmin, vmax=vmax).applymap(
        lambda x: "color: transparent; background-color: transparent"
        if pd.isnull(x)
        else ""
    )

    return pt

# %%
mk_kl_plot()
# Out:
# <pandas.io.formats.style.Styler object at 0x7fde401c3fd0>
# <style type="text/css">
# #T_00000_row0_col0, #T_00000_row1_col13, #T_00000_row5_col5, #T_00000_row8_col11, #T_00000_row11_col8, #T_00000_row13_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_00000_row0_col1, #T_00000_row1_col0, #T_00000_row1_col6, #T_00000_row6_col1 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_00000_row0_col2, #T_00000_row2_col0 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_00000_row0_col3, #T_00000_row0_col4, #T_00000_row3_col0, #T_00000_row4_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_00000_row0_col5, #T_00000_row5_col0 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_00000_row0_col6, #T_00000_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_00000_row0_col7, #T_00000_row0_col13, #T_00000_row7_col0, #T_00000_row13_col0 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_00000_row0_col8, #T_00000_row8_col0 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_00000_row0_col9, #T_00000_row9_col0 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_00000_row0_col10, #T_00000_row10_col0 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_00000_row0_col11, #T_00000_row11_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_00000_row0_col12, #T_00000_row12_col0 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_00000_row0_col14, #T_00000_row14_col0 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_00000_row1_col1, #T_00000_row7_col11, #T_00000_row7_col12, #T_00000_row8_col8, #T_00000_row11_col7, #T_00000_row11_col13, #T_00000_row12_col7, #T_00000_row13_col11 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_00000_row1_col2, #T_00000_row1_col11, #T_00000_row2_col1, #T_00000_row11_col1 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_00000_row1_col3, #T_00000_row1_col4, #T_00000_row2_col14, #T_00000_row3_col1, #T_00000_row4_col1, #T_00000_row14_col2 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_00000_row1_col5, #T_00000_row3_col14, #T_00000_row4_col14, #T_00000_row5_col1, #T_00000_row5_col14, #T_00000_row14_col3, #T_00000_row14_col4, #T_00000_row14_col5 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_00000_row1_col7, #T_00000_row3_col3, #T_00000_row3_col4, #T_00000_row4_col3, #T_00000_row4_col4, #T_00000_row7_col1, #T_00000_row13_col14, #T_00000_row14_col13 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_00000_row1_col8, #T_00000_row2_col11, #T_00000_row8_col1, #T_00000_row11_col2 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_00000_row1_col9, #T_00000_row2_col9, #T_00000_row9_col1, #T_00000_row9_col2 {
#   background-color: #046097;
#   color: #f1f1f1;
# }
# #T_00000_row1_col10, #T_00000_row10_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_00000_row1_col12, #T_00000_row12_col1 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_00000_row1_col14, #T_00000_row14_col1 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_00000_row2_col2, #T_00000_row7_col8, #T_00000_row8_col7, #T_00000_row8_col13, #T_00000_row13_col8 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_00000_row2_col3, #T_00000_row2_col4, #T_00000_row3_col2, #T_00000_row4_col2 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_00000_row2_col5, #T_00000_row5_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_00000_row2_col6, #T_00000_row6_col2 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_00000_row2_col7, #T_00000_row7_col2, #T_00000_row10_col10, #T_00000_row11_col14, #T_00000_row14_col11 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_00000_row2_col8, #T_00000_row2_col12, #T_00000_row6_col7, #T_00000_row7_col6, #T_00000_row8_col2, #T_00000_row12_col2 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_00000_row2_col10, #T_00000_row10_col2 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_00000_row2_col13, #T_00000_row13_col2 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_00000_row3_col5, #T_00000_row4_col5, #T_00000_row5_col3, #T_00000_row5_col4 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_00000_row3_col6, #T_00000_row4_col6, #T_00000_row6_col3, #T_00000_row6_col4 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_00000_row3_col7, #T_00000_row4_col7, #T_00000_row6_col6, #T_00000_row7_col3, #T_00000_row7_col4 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_00000_row3_col8, #T_00000_row4_col8, #T_00000_row8_col3, #T_00000_row8_col4, #T_00000_row9_col13, #T_00000_row10_col12, #T_00000_row12_col10, #T_00000_row13_col9 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_00000_row3_col9, #T_00000_row4_col9, #T_00000_row9_col3, #T_00000_row9_col4 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_00000_row3_col10, #T_00000_row4_col10, #T_00000_row10_col3, #T_00000_row10_col4 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_00000_row3_col11, #T_00000_row4_col11, #T_00000_row11_col3, #T_00000_row11_col4 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_00000_row3_col12, #T_00000_row4_col12, #T_00000_row12_col3, #T_00000_row12_col4 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_00000_row3_col13, #T_00000_row4_col13, #T_00000_row13_col3, #T_00000_row13_col4 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_00000_row5_col6, #T_00000_row6_col5 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_00000_row5_col7, #T_00000_row7_col5 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_00000_row5_col8, #T_00000_row8_col5 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_00000_row5_col9, #T_00000_row9_col5 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_00000_row5_col10, #T_00000_row10_col5 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_00000_row5_col11, #T_00000_row11_col5 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_00000_row5_col12, #T_00000_row6_col11, #T_00000_row11_col6, #T_00000_row12_col5 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_00000_row5_col13, #T_00000_row7_col10, #T_00000_row9_col9, #T_00000_row10_col7, #T_00000_row12_col14, #T_00000_row13_col5, #T_00000_row14_col12 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_00000_row6_col8, #T_00000_row8_col6 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_00000_row6_col9, #T_00000_row9_col6 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_00000_row6_col10, #T_00000_row10_col6 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_00000_row6_col12, #T_00000_row12_col6 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_00000_row6_col13, #T_00000_row13_col6 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_00000_row6_col14, #T_00000_row14_col6 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_00000_row7_col7, #T_00000_row7_col13, #T_00000_row11_col11, #T_00000_row13_col7, #T_00000_row13_col13 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_00000_row7_col9, #T_00000_row9_col7 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_00000_row7_col14, #T_00000_row8_col12, #T_00000_row12_col8, #T_00000_row14_col7 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_00000_row8_col9, #T_00000_row9_col8 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_00000_row8_col10, #T_00000_row10_col8 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_00000_row8_col14, #T_00000_row10_col11, #T_00000_row11_col10, #T_00000_row14_col8 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_00000_row9_col10, #T_00000_row10_col9 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_00000_row9_col11, #T_00000_row11_col9 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_00000_row9_col12, #T_00000_row12_col9 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_00000_row9_col14, #T_00000_row14_col9 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_00000_row10_col13, #T_00000_row13_col10 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_00000_row10_col14, #T_00000_row14_col10 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_00000_row11_col12, #T_00000_row12_col11 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_00000_row12_col12 {
#   background-color: #02395a;
#   color: #f1
