# %% [markdown]
# # Single Table Analysis Template

# %%
# Removes lint errors from VS Code
from typing import Dict, TYPE_CHECKING, Tuple, List

if TYPE_CHECKING:
    import kedro

    catalog: kedro.io.data_catalog.DataCatalog
    session: kedro.framework.session.session.KedroSession
    pipelines: Dict[str, kedro.pipeline.pipeline.Pipeline]

# %%
import os

VIEW = os.getenv("DATASET_VIEW") or "tab_adult"
TABLE = os.getenv("DATASET_TABLE") or "table"
ALG = os.getenv("SYNTH_ALG") or "privbayes"

import numpy as np
import pandas as pd
from pasteur.transform.table import TableTransformer

wrk: pd.DataFrame = catalog.load(f"{VIEW}.wrk.idx_{TABLE}")
alg: pd.DataFrame = catalog.load(f"{VIEW}.{ALG}.idx_{TABLE}")
tst: pd.DataFrame = catalog.load(f"{VIEW}.tst.idx_{TABLE}")

trn: TableTransformer = catalog.load(f"{VIEW}.wrk.trn_{TABLE}")

from pasteur.metadata import Metadata 
params = catalog.load(f"parameters")
meta = Metadata.from_kedro_params(params, VIEW, {TABLE: wrk}).get_table(TABLE)

random_state = catalog.load("params:random_state")

# %%
cols = list(wrk.keys())

a = wrk[cols].to_numpy(dtype="uint16")
b = alg[cols].to_numpy(dtype="uint16")
c = tst[cols].to_numpy(dtype="uint16")

domain = np.concatenate([a, b, c]).max(axis=0) + 1

# %%
from pasteur.math import calc_marginal_1way

# Add at least one sample prob to distr chisquare valid
zero_fill = 1/len(a)

def marg(s: np.ndarray, names: list[str], is_kl = False):
    x = [cols.index(name) for name in names]
    return calc_marginal_1way(s, domain, x, 1e-24 if is_kl else zero_fill)

# %%
from scipy.stats import chisquare

res = []
for split, s in [("alg", b), ("tst", c)]:
    for col in cols:
        k = marg(a, [col])
        j = marg(s, [col])
        chi, p = chisquare(k, j)
        # print(f"{name:12}.{col:20}: X^2={chi:3.3f} p={100*p:7.3f}%")
        res.append([split, col, chi, p])

cs_df = pd.DataFrame(res, columns=["split", "col", "X^2", "p"])

# %%
# res.set_index(keys=["col"]).sort_index().style.background_gradient(axis=0)
cs_df.pivot(
    index=["col"], columns=["split"], values=["X^2", "p"]
).sort_index().style.set_precision(3).background_gradient(
    axis=0, subset=(slice(None), (slice(None), "alg")), cmap='Reds'
).background_gradient(
    axis=0, subset=(slice(None), (slice(None), "tst"))
)
# Out:
# <pandas.io.formats.style.Styler object at 0x7fd9f04e20e0>
# <style type="text/css">
# #T_00000_row0_col0 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_00000_row0_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_00000_row0_col2, #T_00000_row1_col0, #T_00000_row1_col2, #T_00000_row2_col2, #T_00000_row3_col2, #T_00000_row4_col2, #T_00000_row5_col2, #T_00000_row6_col2, #T_00000_row8_col2, #T_00000_row9_col2, #T_00000_row10_col2, #T_00000_row11_col2, #T_00000_row12_col2, #T_00000_row14_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_00000_row0_col3, #T_00000_row1_col3, #T_00000_row2_col3, #T_00000_row3_col3, #T_00000_row4_col3, #T_00000_row5_col3, #T_00000_row6_col3, #T_00000_row8_col3, #T_00000_row9_col1, #T_00000_row9_col3, #T_00000_row10_col3, #T_00000_row11_col3, #T_00000_row12_col3, #T_00000_row14_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_00000_row1_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_00000_row2_col0, #T_00000_row3_col0, #T_00000_row4_col0, #T_00000_row5_col0, #T_00000_row7_col0, #T_00000_row8_col0, #T_00000_row9_col0, #T_00000_row10_col0, #T_00000_row11_col0, #T_00000_row12_col0, #T_00000_row13_col0, #T_00000_row13_col2, #T_00000_row14_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_00000_row2_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_00000_row3_col1, #T_00000_row4_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_00000_row5_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_00000_row6_col0 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_00000_row6_col1 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_00000_row7_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_00000_row7_col2 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_00000_row7_col3, #T_00000_row13_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_00000_row8_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_00000_row10_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_00000_row11_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_00000_row12_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_00000_row13_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_00000_row14_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_00000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00000_level0_col0" class="col_heading level0 col0" colspan="2">X^2</th>
#       <th id="T_00000_level0_col2" class="col_heading level0 col2" colspan="2">p</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >split</th>
#       <th id="T_00000_level1_col0" class="col_heading level1 col0" >alg</th>
#       <th id="T_00000_level1_col1" class="col_heading level1 col1" >tst</th>
#       <th id="T_00000_level1_col2" class="col_heading level1 col2" >alg</th>
#       <th id="T_00000_level1_col3" class="col_heading level1 col3" >tst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00000_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_00000_row0_col0" class="data row0 col0" >0.084</td>
#       <td id="T_00000_row0_col1" class="data row0 col1" >0.002</td>
#       <td id="T_00000_row0_col2" class="data row0 col2" >1.000</td>
#       <td id="T_00000_row0_col3" class="data row0 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row1" class="row_heading level0 row1" >capital-gain</th>
#       <td id="T_00000_row1_col0" class="data row1 col0" >1.753</td>
#       <td id="T_00000_row1_col1" class="data row1 col1" >0.001</td>
#       <td id="T_00000_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_00000_row1_col3" class="data row1 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row2" class="row_heading level0 row2" >capital-loss</th>
#       <td id="T_00000_row2_col0" class="data row2 col0" >0.001</td>
#       <td id="T_00000_row2_col1" class="data row2 col1" >0.001</td>
#       <td id="T_00000_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_00000_row2_col3" class="data row2 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_00000_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_00000_row3_col1" class="data row3 col1" >0.001</td>
#       <td id="T_00000_row3_col2" class="data row3 col2" >1.000</td>
#       <td id="T_00000_row3_col3" class="data row3 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row4" class="row_heading level0 row4" >education-num</th>
#       <td id="T_00000_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_00000_row4_col1" class="data row4 col1" >0.001</td>
#       <td id="T_00000_row4_col2" class="data row4 col2" >1.000</td>
#       <td id="T_00000_row4_col3" class="data row4 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row5" class="row_heading level0 row5" >fnlwgt</th>
#       <td id="T_00000_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_00000_row5_col1" class="data row5 col1" >0.002</td>
#       <td id="T_00000_row5_col2" class="data row5 col2" >1.000</td>
#       <td id="T_00000_row5_col3" class="data row5 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row6" class="row_heading level0 row6" >hours-per-week</th>
#       <td id="T_00000_row6_col0" class="data row6 col0" >0.466</td>
#       <td id="T_00000_row6_col1" class="data row6 col1" >0.003</td>
#       <td id="T_00000_row6_col2" class="data row6 col2" >1.000</td>
#       <td id="T_00000_row6_col3" class="data row6 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row7" class="row_heading level0 row7" >income</th>
#       <td id="T_00000_row7_col0" class="data row7 col0" >0.000</td>
#       <td id="T_00000_row7_col1" class="data row7 col1" >0.000</td>
#       <td id="T_00000_row7_col2" class="data row7 col2" >1.000</td>
#       <td id="T_00000_row7_col3" class="data row7 col3" >0.992</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row8" class="row_heading level0 row8" >marital-status</th>
#       <td id="T_00000_row8_col0" class="data row8 col0" >0.000</td>
#       <td id="T_00000_row8_col1" class="data row8 col1" >0.000</td>
#       <td id="T_00000_row8_col2" class="data row8 col2" >1.000</td>
#       <td id="T_00000_row8_col3" class="data row8 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row9" class="row_heading level0 row9" >native-country</th>
#       <td id="T_00000_row9_col0" class="data row9 col0" >0.001</td>
#       <td id="T_00000_row9_col1" class="data row9 col1" >0.004</td>
#       <td id="T_00000_row9_col2" class="data row9 col2" >1.000</td>
#       <td id="T_00000_row9_col3" class="data row9 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row10" class="row_heading level0 row10" >occupation</th>
#       <td id="T_00000_row10_col0" class="data row10 col0" >0.000</td>
#       <td id="T_00000_row10_col1" class="data row10 col1" >0.002</td>
#       <td id="T_00000_row10_col2" class="data row10 col2" >1.000</td>
#       <td id="T_00000_row10_col3" class="data row10 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row11" class="row_heading level0 row11" >race</th>
#       <td id="T_00000_row11_col0" class="data row11 col0" >0.000</td>
#       <td id="T_00000_row11_col1" class="data row11 col1" >0.000</td>
#       <td id="T_00000_row11_col2" class="data row11 col2" >1.000</td>
#       <td id="T_00000_row11_col3" class="data row11 col3" >1.000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row12" class="row_heading level0 row12" >relationship</th>
#       <td id="T_00000_row12_col0" class="data row12 col0" >0.000</td>
#       <td id="T_00000_row12_col1" class="data row12 col1" >0.000</td>
#       <td id="T_00000_row12_col2" class="data row12 col2" >1.000</td>
#       <td id="T_00000_row1

# %%
diff_df = cs_df.pivot(
    index=["col"], columns=[], values=["X^2", "p", "split"]
)
diff_df = diff_df[diff_df["split"] == "alg"].drop(columns=["split"]) - diff_df[diff_df["split"] == "tst"].drop(columns=["split"])

cs_gmap = diff_df / diff_df.abs().max(axis=0) / 2 + 0.5
cs_gmap = cs_gmap.sort_index().to_numpy()

# %%
cs_df.pivot(
    index=["col"], columns=["split"], values=["X^2", "p"]
).sort_index().style.background_gradient(
    axis=0, subset=(slice(None), (slice(None), "tst"))#, cmap="Greys"
).background_gradient(
    axis=None, subset=(slice(None), (slice(None), "alg")), cmap="RdBu", vmin=0, vmax=1, gmap=cs_gmap
)
# Out:
# <pandas.io.formats.style.Styler object at 0x7fd9efa66950>
# <style type="text/css">
# #T_00000_row0_col0 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_00000_row0_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_00000_row0_col2, #T_00000_row2_col2, #T_00000_row3_col2, #T_00000_row4_col2, #T_00000_row5_col2, #T_00000_row6_col2, #T_00000_row8_col2, #T_00000_row9_col2, #T_00000_row10_col2, #T_00000_row11_col0, #T_00000_row12_col2, #T_00000_row14_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_00000_row0_col3, #T_00000_row1_col3, #T_00000_row2_col3, #T_00000_row3_col3, #T_00000_row4_col3, #T_00000_row5_col3, #T_00000_row6_col3, #T_00000_row8_col3, #T_00000_row9_col1, #T_00000_row9_col3, #T_00000_row10_col3, #T_00000_row11_col3, #T_00000_row12_col3, #T_00000_row14_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_00000_row1_col0, #T_00000_row7_col2 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_00000_row1_col1 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_00000_row1_col2, #T_00000_row2_col0, #T_00000_row3_col0, #T_00000_row4_col0, #T_00000_row5_col0, #T_00000_row7_col0, #T_00000_row8_col0, #T_00000_row9_col0, #T_00000_row10_col0, #T_00000_row11_col2, #T_00000_row12_col0, #T_00000_row13_col0, #T_00000_row14_col0 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_00000_row2_col1 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_00000_row3_col1, #T_00000_row4_col1 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_00000_row5_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_00000_row6_col0 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_00000_row6_col1 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_00000_row7_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_00000_row7_col3, #T_00000_row13_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_00000_row8_col1 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_00000_row10_col1 {
#   background-color: #3b92c1;
#   color: #f1f1f1;
# }
# #T_00000_row11_col1 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_00000_row12_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_00000_row13_col2 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_00000_row13_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_00000_row14_col1 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# </style>
# <table id="T_00000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00000_level0_col0" class="col_heading level0 col0" colspan="2">X^2</th>
#       <th id="T_00000_level0_col2" class="col_heading level0 col2" colspan="2">p</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >split</th>
#       <th id="T_00000_level1_col0" class="col_heading level1 col0" >alg</th>
#       <th id="T_00000_level1_col1" class="col_heading level1 col1" >tst</th>
#       <th id="T_00000_level1_col2" class="col_heading level1 col2" >alg</th>
#       <th id="T_00000_level1_col3" class="col_heading level1 col3" >tst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00000_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_00000_row0_col0" class="data row0 col0" >0.084453</td>
#       <td id="T_00000_row0_col1" class="data row0 col1" >0.001818</td>
#       <td id="T_00000_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_00000_row0_col3" class="data row0 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row1" class="row_heading level0 row1" >capital-gain</th>
#       <td id="T_00000_row1_col0" class="data row1 col0" >1.753099</td>
#       <td id="T_00000_row1_col1" class="data row1 col1" >0.000749</td>
#       <td id="T_00000_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_00000_row1_col3" class="data row1 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row2" class="row_heading level0 row2" >capital-loss</th>
#       <td id="T_00000_row2_col0" class="data row2 col0" >0.000797</td>
#       <td id="T_00000_row2_col1" class="data row2 col1" >0.001481</td>
#       <td id="T_00000_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_00000_row2_col3" class="data row2 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_00000_row3_col0" class="data row3 col0" >0.000194</td>
#       <td id="T_00000_row3_col1" class="data row3 col1" >0.001140</td>
#       <td id="T_00000_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_00000_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row4" class="row_heading level0 row4" >education-num</th>
#       <td id="T_00000_row4_col0" class="data row4 col0" >0.000194</td>
#       <td id="T_00000_row4_col1" class="data row4 col1" >0.001140</td>
#       <td id="T_00000_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_00000_row4_col3" class="data row4 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row5" class="row_heading level0 row5" >fnlwgt</th>
#       <td id="T_00000_row5_col0" class="data row5 col0" >0.000397</td>
#       <td id="T_00000_row5_col1" class="data row5 col1" >0.002013</td>
#       <td id="T_00000_row5_col2" class="data row5 col2" >1.000000</td>
#       <td id="T_00000_row5_col3" class="data row5 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row6" class="row_heading level0 row6" >hours-per-week</th>
#       <td id="T_00000_row6_col0" class="data row6 col0" >0.465833</td>
#       <td id="T_00000_row6_col1" class="data row6 col1" >0.003205</td>
#       <td id="T_00000_row6_col2" class="data row6 col2" >1.000000</td>
#       <td id="T_00000_row6_col3" class="data row6 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row7" class="row_heading level0 row7" >income</th>
#       <td id="T_00000_row7_col0" class="data row7 col0" >0.000000</td>
#       <td id="T_00000_row7_col1" class="data row7 col1" >0.000095</td>
#       <td id="T_00000_row7_col2" class="data row7 col2" >0.999885</td>
#       <td id="T_00000_row7_col3" class="data row7 col3" >0.992243</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row8" class="row_heading level0 row8" >marital-status</th>
#       <td id="T_00000_row8_col0" class="data row8 col0" >0.000021</td>
#       <td id="T_00000_row8_col1" class="data row8 col1" >0.000498</td>
#       <td id="T_00000_row8_col2" class="data row8 col2" >1.000000</td>
#       <td id="T_00000_row8_col3" class="data row8 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row9" class="row_heading level0 row9" >native-country</th>
#       <td id="T_00000_row9_col0" class="data row9 col0" >0.000672</td>
#       <td id="T_00000_row9_col1" class="data row9 col1" >0.003623</td>
#       <td id="T_00000_row9_col2" class="data row9 col2" >1.000000</td>
#       <td id="T_00000_row9_col3" class="data row9 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row10" class="row_heading level0 row10" >occupation</th>
#       <td id="T_00000_row10_col0" class="data row10 col0" >0.000209</td>
#       <td id="T_00000_row10_col1" class="data row10 col1" >0.002237</td>
#       <td id="T_00000_row10_col2" class="data row10 col2" >1.000000</td>
#       <td id="T_00000_row10_col3" class="data row10 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row11" class="row_heading level0 row11" >race</th>
#       <td id="T_00000_row11_col0" class="data row11 col0" >0.000251</td>
#       <td id="T_00000_row11_col1" class="data row11 col1" >0.000173</td>
#       <td id="T_00000_row11_col2" class="data row11 col2" >1.000000</td>
#       <td id="T_00000_row11_col3" class="data row11 col3" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row12" class="row_heading level0 row12" >relationship</th>
#       <td id="T_00000_row12_col0" class="d

# %%
from scipy.special import rel_entr

res = []
for col_i in cols:
    for col_j in cols:
        for split, s in [("alg", b), ("tst", c)]:
            k = marg(a, [col_i, col_j], True)
            j = marg(s, [col_i, col_j], True)
            
            kl = rel_entr(k, j).sum()
            kl_norm = 1 / (1 + kl)
            res.append([split, col_i, col_j, kl, kl_norm, len(k)])

kl_df = pd.DataFrame(
    res,
    columns=[
        "split",
        "col_i",
        "col_j",
        "kl",
        "kl_norm",
        "mlen",
    ],
)
kl_df.head().style
# Out:
# <pandas.io.formats.style.Styler object at 0x7fd9f04e1d80>
# <style type="text/css">
# </style>
# <table id="T_00000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00000_level0_col0" class="col_heading level0 col0" >split</th>
#       <th id="T_00000_level0_col1" class="col_heading level0 col1" >col_i</th>
#       <th id="T_00000_level0_col2" class="col_heading level0 col2" >col_j</th>
#       <th id="T_00000_level0_col3" class="col_heading level0 col3" >kl</th>
#       <th id="T_00000_level0_col4" class="col_heading level0 col4" >kl_norm</th>
#       <th id="T_00000_level0_col5" class="col_heading level0 col5" >mlen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00000_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00000_row0_col0" class="data row0 col0" >alg</td>
#       <td id="T_00000_row0_col1" class="data row0 col1" >age</td>
#       <td id="T_00000_row0_col2" class="data row0 col2" >age</td>
#       <td id="T_00000_row0_col3" class="data row0 col3" >0.054128</td>
#       <td id="T_00000_row0_col4" class="data row0 col4" >0.948651</td>
#       <td id="T_00000_row0_col5" class="data row0 col5" >1089</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00000_row1_col0" class="data row1 col0" >tst</td>
#       <td id="T_00000_row1_col1" class="data row1 col1" >age</td>
#       <td id="T_00000_row1_col2" class="data row1 col2" >age</td>
#       <td id="T_00000_row1_col3" class="data row1 col3" >0.000914</td>
#       <td id="T_00000_row1_col4" class="data row1 col4" >0.999086</td>
#       <td id="T_00000_row1_col5" class="data row1 col5" >1089</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00000_row2_col0" class="data row2 col0" >alg</td>
#       <td id="T_00000_row2_col1" class="data row2 col1" >age</td>
#       <td id="T_00000_row2_col2" class="data row2 col2" >workclass</td>
#       <td id="T_00000_row2_col3" class="data row2 col3" >0.076616</td>
#       <td id="T_00000_row2_col4" class="data row2 col4" >0.928836</td>
#       <td id="T_00000_row2_col5" class="data row2 col5" >297</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00000_row3_col0" class="data row3 col0" >tst</td>
#       <td id="T_00000_row3_col1" class="data row3 col1" >age</td>
#       <td id="T_00000_row3_col2" class="data row3 col2" >workclass</td>
#       <td id="T_00000_row3_col3" class="data row3 col3" >0.055948</td>
#       <td id="T_00000_row3_col4" class="data row3 col4" >0.947016</td>
#       <td id="T_00000_row3_col5" class="data row3 col5" >297</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00000_row4_col0" class="data row4 col0" >alg</td>
#       <td id="T_00000_row4_col1" class="data row4 col1" >age</td>
#       <td id="T_00000_row4_col2" class="data row4 col2" >fnlwgt</td>
#       <td id="T_00000_row4_col3" class="data row4 col3" >0.107825</td>
#       <td id="T_00000_row4_col4" class="data row4 col4" >0.902670</td>
#       <td id="T_00000_row4_col5" class="data row4 col5" >1089</td>
#     </tr>
#   </tbody>
# </table>

# %%
def mk_kl_plot(filter=None, val="kl_norm"):
    pt = kl_df[filter] if filter is not None else kl_df
    pt = pt.pivot(
        values=val, index=["col_j"], columns=["col_i", "split"]
    ).sort_index(axis=0).sort_index(axis=1)

    pt = pt.style.set_precision(3).background_gradient(
        axis=None, subset=(slice(None), (slice(None), "alg")), cmap='Reds'
    ).background_gradient(
        axis=None, subset=(slice(None), (slice(None), "tst"))
    ).applymap(
        lambda x: "color: transparent; background-color: transparent"
        if pd.isnull(x)
        else ""
    )

    return pt
mk_kl_plot(val="kl_norm")
# Out:
# <pandas.io.formats.style.Styler object at 0x7fd9f0172680>
# <style type="text/css">
# #T_00000_row0_col0, #T_00000_row0_col26, #T_00000_row13_col0 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_00000_row0_col1, #T_00000_row3_col7, #T_00000_row3_col9, #T_00000_row4_col7, #T_00000_row4_col9, #T_00000_row7_col15, #T_00000_row7_col17, #T_00000_row7_col23, #T_00000_row7_col25, #T_00000_row7_col27, #T_00000_row8_col15, #T_00000_row8_col17, #T_00000_row8_col27, #T_00000_row10_col21, #T_00000_row11_col15, #T_00000_row11_col23, #T_00000_row11_col25, #T_00000_row11_col27, #T_00000_row12_col15, #T_00000_row12_col23, #T_00000_row12_col25, #T_00000_row13_col15, #T_00000_row13_col17, #T_00000_row13_col23, #T_00000_row13_col27, #T_00000_row13_col29, #T_00000_row14_col27, #T_00000_row14_col29 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_00000_row0_col2, #T_00000_row1_col0 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_00000_row0_col3, #T_00000_row1_col1 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_00000_row0_col4, #T_00000_row2_col0 {
#   background-color: #f44f39;
#   color: #f1f1f1;
# }
# #T_00000_row0_col5, #T_00000_row2_col1 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_00000_row0_col6, #T_00000_row0_col8, #T_00000_row3_col0, #T_00000_row4_col0 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_00000_row0_col7, #T_00000_row0_col9, #T_00000_row3_col1, #T_00000_row4_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_00000_row0_col10, #T_00000_row5_col0 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_00000_row0_col11, #T_00000_row5_col1, #T_00000_row5_col19, #T_00000_row9_col11 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_00000_row0_col12, #T_00000_row6_col0 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_00000_row0_col13, #T_00000_row6_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_00000_row0_col14, #T_00000_row7_col0 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_00000_row0_col15, #T_00000_row3_col17, #T_00000_row4_col17, #T_00000_row7_col1, #T_00000_row8_col7, #T_00000_row8_col9 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_00000_row0_col16, #T_00000_row8_col0 {
#   background-color: #bb141a;
#   color: #f1f1f1;
# }
# #T_00000_row0_col17, #T_00000_row3_col21, #T_00000_row4_col21, #T_00000_row6_col29, #T_00000_row8_col1, #T_00000_row10_col7, #T_00000_row10_col9, #T_00000_row14_col13 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_00000_row0_col18, #T_00000_row9_col0 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_00000_row0_col19, #T_00000_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_00000_row0_col20, #T_00000_row10_col0 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_00000_row0_col21, #T_00000_row10_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_00000_row0_col22, #T_00000_row11_col0 {
#   background-color: #bf151b;
#   color: #f1f1f1;
# }
# #T_00000_row0_col23, #T_00000_row11_col1 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_00000_row0_col24, #T_00000_row12_col0 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_00000_row0_col25, #T_00000_row5_col29, #T_00000_row12_col1, #T_00000_row14_col11 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_00000_row0_col27, #T_00000_row1_col3, #T_00000_row1_col15, #T_00000_row3_col15, #T_00000_row3_col27, #T_00000_row4_col15, #T_00000_row4_col27, #T_00000_row6_col13, #T_00000_row7_col3, #T_00000_row7_col7, #T_00000_row7_col9, #T_00000_row8_col23, #T_00000_row8_col25, #T_00000_row9_col19, #T_00000_row10_col27, #T_00000_row11_col17, #T_00000_row12_col17, #T_00000_row13_col1, #T_00000_row13_col7, #T_00000_row13_col9, #T_00000_row13_col21 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_00000_row0_col28, #T_00000_row14_col0 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_00000_row0_col29, #T_00000_row14_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_00000_row1_col2, #T_00000_row1_col14, #T_00000_row1_col24, #T_00000_row7_col2, #T_00000_row12_col2 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_00000_row1_col4, #T_00000_row2_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_00000_row1_col5, #T_00000_row2_col3 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_00000_row1_col6, #T_00000_row1_col8, #T_00000_row1_col22, #T_00000_row3_col2, #T_00000_row4_col2, #T_00000_row11_col2 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_00000_row1_col7, #T_00000_row1_col9, #T_00000_row2_col25, #T_00000_row3_col3, #T_00000_row4_col3, #T_00000_row12_col5 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_00000_row1_col10, #T_00000_row5_col2 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_00000_row1_col11, #T_00000_row5_col3 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_00000_row1_col12, #T_00000_row6_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_00000_row1_col13, #T_00000_row6_col3 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_00000_row1_col16, #T_00000_row6_col18, #T_00000_row8_col2, #T_00000_row9_col12 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_00000_row1_col17, #T_00000_row3_col23, #T_00000_row4_col23, #T_00000_row8_col3, #T_00000_row11_col7, #T_00000_row11_col9 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_00000_row1_col18, #T_00000_row9_col2 {
#   background-color: #fdc9b3;
#   color: #000000;
# }
# #T_00000_row1_col19, #T_00000_row9_col3 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_00000_row1_col20, #T_00000_row10_col2 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_00000_row1_col21, #T_00000_row10_col3 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_00000_row1_col23, #T_00000_row2_col15, #T_00000_row5_col11, #T_00000_row6_col15, #T_00000_row7_col5, #T_00000_row7_col13, #T_00000_row11_col3 {
#   background-color: #023d60;
#   color: #f1f1f1;
# }
# #T_00000_row1_col25, #T_00000_row12_col3 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_00000_row1_col26, #T_00000_row1_col28, #T_00000_row13_col2, #T_00000_row14_col2 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_00000_row1_col27, #T_00000_row2_col5, #T_00000_row7_col21, #T_00000_row8_col21, #T_00000_row8_col29, #T_00000_row10_col15, #T_00000_row10_col17, #T_00000_row11_col29, #T_00000_row12_col27, #T_00000_row13_col3, #T_00000_row13_col25, #T_00000_row14_col17, #T_00000_row14_col23 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_00000_row1_col29, #T_00000_row14_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_00000_row2_col4, #T_00000_row2_col14, #T_00000_row7_col4, #T_00000_row8_col20, #T_00000_row8_col22, #T_00000_row10_col16, #T_00000_row11_col16 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_00000_row2_col6, #T_00000_row2_col8, #T_00000_row2_col20, #T_00000_row3_col4, #T_00000_row4_col4, #T_00000_row9_col24, #T_00000_row10_col4, #T_00000_row12_col18 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_00000_row2_col7, #T_00000_row2_col9, #T_00000_row3_col5, #T_00000_row4_col5 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_00000_row2_col10, #T_00000_row5_col4 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_00000_row2_col11, #T_00000_row5_col5 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_00000_row2_col12, #T_00000_row6_col4 {
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# #T_00000_row2_col13, #T_00000_row6_col5 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_00000_row2_col16, #T_00000_row8_col4 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_00000_row2_col17, #T_00000_row8_col5 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_00000_row2_col18, #T_00000_row9_col4 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_00000_row2_col19, #T_00000_row9_col5 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_00000_row2_col21, #T_00000_row10_col5 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_00000_row2_col22, #T_00000_row2_col26, #T_00000_row11_col4, #T_00000_row13_col4 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_00000_row2_col23, #T_00000_row5_col23, #T_00000_row11_col5, #T_00000_row11_col11 {
#   background-color: #034d

# %%
def color_dataframe(
    df: pd.DataFrame,
    idx: list[str],
    cols: list[str],
    vals: list[str],
    ref_split="tst",
    split_col="split",
    cmap="BrBG",
    cmap_ref="Purples",
    diff_reverse=True,
    formatters: dict[str, dict] | None = None,
):
    pt = (
        df.pivot(index=idx, columns=[*cols, split_col], values=vals)
        .sort_index(0)
        .sort_index(1)
    )
    pts = pt.style

    if formatters:
        for col, form in formatters.items():
            pts = pts.format(
                subset=(
                    slice(None),
                    (col, *[slice(None) for _ in range(len(cols) + 1)]),
                ),
                **form
            )

    # Apply background style to ref columns
    for col in vals:
        pts = pts.background_gradient(
            axis=None,
            subset=(
                slice(None),
                (col, *[slice(None) for _ in range(len(cols))], ref_split),
            ),
            cmap=cmap_ref,
        )

    # Apply background to non-ref columns
    # It is based in the difference between expected value to resulting value
    # red = too low
    # white = same, good
    # white = too high
    df_ref = (
        df[df[split_col] == ref_split]
        .pivot(index=idx, columns=cols, values=vals)
        .sort_index(0)
        .sort_index(1)
    )
    splits = df[split_col].unique()
    for split in splits:
        if split == ref_split:
            continue

        df_split = (
            df[df[split_col] == split]
            .pivot(index=idx, columns=cols, values=vals)
            .sort_index(0)
            .sort_index(1)
        )
        df_diff = df_split - df_ref
        if diff_reverse:
            df_diff = -df_diff
        df_norm = df_diff / df_diff.abs().max(axis=0) / 2 + 0.5

        pts = pts.background_gradient(
            axis=None,
            subset=(
                slice(None),
                (*[slice(None) for _ in range(len(cols) + 1)], split),
            ),
            gmap=df_norm.to_numpy(),
            vmin=0,
            vmax=1,
            cmap=cmap,
        )

    return pts

# %%
kl_formatters = {
    "kl_norm": {"precision": 3}
}
color_dataframe(kl_df, idx=["col_j"], cols=["col_i"], vals=["kl_norm"], formatters=kl_formatters)
# Out:
# <pandas.io.formats.style.Styler object at 0x7fd9f0172230>
# <style type="text/css">
# #T_00000_row0_col0 {
#   background-color: #b9e4de;
#   color: #000000;
# }
# #T_00000_row0_col1, #T_00000_row3_col7, #T_00000_row3_col9, #T_00000_row4_col7, #T_00000_row4_col9, #T_00000_row7_col15, #T_00000_row7_col17, #T_00000_row7_col23, #T_00000_row7_col25, #T_00000_row7_col27, #T_00000_row8_col15, #T_00000_row8_col17, #T_00000_row8_col27, #T_00000_row10_col21, #T_00000_row11_col15, #T_00000_row11_col23, #T_00000_row11_col25, #T_00000_row11_col27, #T_00000_row12_col15, #T_00000_row12_col23, #T_00000_row12_col25, #T_00000_row13_col15, #T_00000_row13_col17, #T_00000_row13_col23, #T_00000_row13_col27, #T_00000_row13_col29, #T_00000_row14_col27, #T_00000_row14_col29 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_00000_row0_col2 {
#   background-color: #015b52;
#   color: #f1f1f1;
# }
# #T_00000_row0_col3, #T_00000_row1_col1 {
#   background-color: #62429c;
#   color: #f1f1f1;
# }
# #T_00000_row0_col4, #T_00000_row8_col10, #T_00000_row9_col16, #T_00000_row10_col6, #T_00000_row10_col8, #T_00000_row11_col18 {
#   background-color: #f4e5be;
#   color: #000000;
# }
# #T_00000_row0_col5, #T_00000_row2_col1 {
#   background-color: #928fc3;
#   color: #f1f1f1;
# }
# #T_00000_row0_col6, #T_00000_row0_col8 {
#   background-color: #f6eac9;
#   color: #000000;
# }
# #T_00000_row0_col7, #T_00000_row0_col9, #T_00000_row3_col1, #T_00000_row4_col1 {
#   background-color: #8582bc;
#   color: #f1f1f1;
# }
# #T_00000_row0_col10 {
#   background-color: #d6af65;
#   color: #000000;
# }
# #T_00000_row0_col11, #T_00000_row5_col1, #T_00000_row5_col19, #T_00000_row9_col11 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_00000_row0_col12, #T_00000_row0_col20 {
#   background-color: #f6e9c7;
#   color: #000000;
# }
# #T_00000_row0_col13, #T_00000_row6_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_00000_row0_col14 {
#   background-color: #c7eae5;
#   color: #000000;
# }
# #T_00000_row0_col15, #T_00000_row3_col17, #T_00000_row4_col17, #T_00000_row7_col1, #T_00000_row8_col7, #T_00000_row8_col9 {
#   background-color: #440a82;
#   color: #f1f1f1;
# }
# #T_00000_row0_col16, #T_00000_row8_col0 {
#   background-color: #edf3f2;
#   color: #000000;
# }
# #T_00000_row0_col17, #T_00000_row3_col21, #T_00000_row4_col21, #T_00000_row6_col29, #T_00000_row8_col1, #T_00000_row10_col7, #T_00000_row10_col9, #T_00000_row14_col13 {
#   background-color: #552a90;
#   color: #f1f1f1;
# }
# #T_00000_row0_col18, #T_00000_row9_col0 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_00000_row0_col19, #T_00000_row9_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_00000_row0_col21, #T_00000_row10_col1 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_00000_row0_col22 {
#   background-color: #e4f1ef;
#   color: #000000;
# }
# #T_00000_row0_col23, #T_00000_row11_col1 {
#   background-color: #53268f;
#   color: #f1f1f1;
# }
# #T_00000_row0_col24, #T_00000_row6_col20 {
#   background-color: #e9f2f1;
#   color: #000000;
# }
# #T_00000_row0_col25, #T_00000_row5_col29, #T_00000_row12_col1, #T_00000_row14_col11 {
#   background-color: #54278f;
#   color: #f1f1f1;
# }
# #T_00000_row0_col26 {
#   background-color: #b6e3dd;
#   color: #000000;
# }
# #T_00000_row0_col27, #T_00000_row1_col3, #T_00000_row1_col15, #T_00000_row3_col15, #T_00000_row3_col27, #T_00000_row4_col15, #T_00000_row4_col27, #T_00000_row6_col13, #T_00000_row7_col3, #T_00000_row7_col7, #T_00000_row7_col9, #T_00000_row8_col23, #T_00000_row8_col25, #T_00000_row9_col19, #T_00000_row10_col27, #T_00000_row11_col17, #T_00000_row12_col17, #T_00000_row13_col1, #T_00000_row13_col7, #T_00000_row13_col9, #T_00000_row13_col21 {
#   background-color: #40017e;
#   color: #f1f1f1;
# }
# #T_00000_row0_col28 {
#   background-color: #def0ed;
#   color: #000000;
# }
# #T_00000_row0_col29, #T_00000_row14_col1 {
#   background-color: #572c92;
#   color: #f1f1f1;
# }
# #T_00000_row1_col0 {
#   background-color: #01655d;
#   color: #f1f1f1;
# }
# #T_00000_row1_col2, #T_00000_row1_col4, #T_00000_row1_col6, #T_00000_row1_col8, #T_00000_row1_col10, #T_00000_row1_col12, #T_00000_row1_col14, #T_00000_row1_col16, #T_00000_row1_col20, #T_00000_row1_col22, #T_00000_row1_col24, #T_00000_row1_col26, #T_00000_row1_col28, #T_00000_row2_col2 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_00000_row1_col5, #T_00000_row2_col3 {
#   background-color: #42057f;
#   color: #f1f1f1;
# }
# #T_00000_row1_col7, #T_00000_row1_col9, #T_00000_row2_col25, #T_00000_row3_col3, #T_00000_row4_col3, #T_00000_row12_col5 {
#   background-color: #51218c;
#   color: #f1f1f1;
# }
# #T_00000_row1_col11, #T_00000_row5_col3 {
#   background-color: #50208c;
#   color: #f1f1f1;
# }
# #T_00000_row1_col13, #T_00000_row6_col3 {
#   background-color: #684da1;
#   color: #f1f1f1;
# }
# #T_00000_row1_col17, #T_00000_row3_col23, #T_00000_row4_col23, #T_00000_row8_col3, #T_00000_row11_col7, #T_00000_row11_col9 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_00000_row1_col18 {
#   background-color: #1d8078;
#   color: #f1f1f1;
# }
# #T_00000_row1_col19, #T_00000_row9_col3 {
#   background-color: #64459e;
#   color: #f1f1f1;
# }
# #T_00000_row1_col21, #T_00000_row10_col3 {
#   background-color: #4d1b89;
#   color: #f1f1f1;
# }
# #T_00000_row1_col23, #T_00000_row2_col15, #T_00000_row5_col11, #T_00000_row6_col15, #T_00000_row7_col5, #T_00000_row7_col13, #T_00000_row11_col3 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_00000_row1_col25, #T_00000_row12_col3 {
#   background-color: #460c83;
#   color: #f1f1f1;
# }
# #T_00000_row1_col27, #T_00000_row2_col5, #T_00000_row7_col21, #T_00000_row8_col21, #T_00000_row8_col29, #T_00000_row10_col15, #T_00000_row10_col17, #T_00000_row11_col29, #T_00000_row12_col27, #T_00000_row13_col3, #T_00000_row13_col25, #T_00000_row14_col17, #T_00000_row14_col23 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_00000_row1_col29, #T_00000_row14_col3 {
#   background-color: #481084;
#   color: #f1f1f1;
# }
# #T_00000_row2_col0, #T_00000_row2_col28, #T_00000_row3_col20, #T_00000_row4_col20 {
#   background-color: #f5e7c0;
#   color: #000000;
# }
# #T_00000_row2_col4, #T_00000_row2_col24, #T_00000_row2_col26, #T_00000_row3_col6, #T_00000_row3_col8, #T_00000_row3_col14, #T_00000_row4_col6, #T_00000_row4_col8, #T_00000_row4_col14, #T_00000_row7_col6, #T_00000_row7_col8, #T_00000_row7_col14, #T_00000_row7_col16, #T_00000_row7_col24, #T_00000_row7_col28, #T_00000_row8_col14, #T_00000_row8_col16, #T_00000_row8_col24, #T_00000_row8_col26, #T_00000_row9_col18, #T_00000_row10_col20, #T_00000_row10_col26, #T_00000_row11_col24, #T_00000_row12_col4, #T_00000_row12_col14, #T_00000_row12_col16, #T_00000_row12_col22, #T_00000_row12_col24, #T_00000_row12_col28, #T_00000_row13_col4, #T_00000_row13_col16, #T_00000_row13_col26, #T_00000_row13_col28, #T_00000_row14_col14, #T_00000_row14_col24, #T_00000_row14_col26, #T_00000_row14_col28 {
#   background-color: #f5f5f4;
#   color: #000000;
# }
# #T_00000_row2_col6, #T_00000_row2_col8 {
#   background-color: #d4ac62;
#   color: #000000;
# }
# #T_00000_row2_col7, #T_00000_row2_col9, #T_00000_row3_col5, #T_00000_row4_col5 {
#   background-color: #715faa;
#   color: #f1f1f1;
# }
# #T_00000_row2_col10 {
#   background-color: #e8d097;
#   color: #000000;
# }
# #T_00000_row2_col11, #T_00000_row5_col5 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_00000_row2_col12, #T_00000_row6_col4 {
#   background-color: #e0f0ee;
#   color: #000000;
# }
# #T_00000_row2_col13, #T_00000_row6_col5 {
#   background-color: #8380bb;
#   color: #f1f1f1;
# }
# #T_00000_row2_col14, #T_00000_row5_col14, #T_00000_row7_col4, #T_00000_row10_col24, #T_00000_row10_col28, #T_00000_row11_col20, #T_00000_row12_col20, #T_00000_row14_col20 {
#   background-color: #f5f4f0;
#   color: #000000;
# }
# #T_00000_row2_col16, #T_00000_row3_col16, #T_00000_row3_col28, #T_00000_row4_col16, #T_00000_row4_col28, #T_00000_row7_col22, #T_00000_row7_col26, #T_00000_row8_col4, #T_00000_row8_col6, #T_00000_row8_col8, #T_00000_row11_col14, #T_00000_row11_col22, #T_00000_row11_col26, #T_00000_row13_col14, #T_00000_row13_col22, #T_00000_row14_col6, #T_00000_row14_col8 {
#   background-color: #f4f5f5;
#   color: #000000;
# }
# #T_00000_row2_col17, #T_00000_row8_col5 {
#   background-color: #4f1f8b;
#   color: #f1f1f1;
# }
# #T_00000_row2_col18 {
#   background-col

# %%
cs_formatters = {
    "X^2": {"precision": 3},
    "p": {"formatter": lambda x: f"{100*x:.1f}"}
}
color_dataframe(cs_df, idx=["col"], cols=[], vals=["X^2", "p"], formatters=cs_formatters)
# Out:
# <pandas.io.formats.style.Styler object at 0x7fd9f03fe230>
# <style type="text/css">
# #T_00000_row0_col0 {
#   background-color: #f5f2e8;
#   color: #000000;
# }
# #T_00000_row0_col1 {
#   background-color: #9e9bc8;
#   color: #f1f1f1;
# }
# #T_00000_row0_col2, #T_00000_row1_col2, #T_00000_row2_col0, #T_00000_row2_col2, #T_00000_row3_col0, #T_00000_row3_col2, #T_00000_row4_col0, #T_00000_row4_col2, #T_00000_row5_col0, #T_00000_row5_col2, #T_00000_row6_col2, #T_00000_row7_col0, #T_00000_row8_col0, #T_00000_row9_col0, #T_00000_row9_col2, #T_00000_row10_col0, #T_00000_row10_col2, #T_00000_row11_col2, #T_00000_row12_col0, #T_00000_row13_col0, #T_00000_row14_col0 {
#   background-color: #f4f5f5;
#   color: #000000;
# }
# #T_00000_row0_col3, #T_00000_row1_col3, #T_00000_row2_col3, #T_00000_row3_col3, #T_00000_row4_col3, #T_00000_row5_col3, #T_00000_row6_col3, #T_00000_row8_col3, #T_00000_row9_col1, #T_00000_row9_col3, #T_00000_row10_col3, #T_00000_row11_col3, #T_00000_row12_col3, #T_00000_row14_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_00000_row1_col0, #T_00000_row7_col2 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_00000_row1_col1 {
#   background-color: #e2e2ef;
#   color: #000000;
# }
# #T_00000_row2_col1 {
#   background-color: #b5b5d7;
#   color: #000000;
# }
# #T_00000_row3_col1, #T_00000_row4_col1 {
#   background-color: #cccce4;
#   color: #000000;
# }
# #T_00000_row5_col1 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_00000_row6_col0 {
#   background-color: #efdcad;
#   color: #000000;
# }
# #T_00000_row6_col1 {
#   background-color: #52238d;
#   color: #f1f1f1;
# }
# #T_00000_row7_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_00000_row7_col3, #T_00000_row13_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_00000_row8_col1 {
#   background-color: #eeecf5;
#   color: #000000;
# }
# #T_00000_row8_col2, #T_00000_row11_col0, #T_00000_row12_col2, #T_00000_row14_col2 {
#   background-color: #f5f5f4;
#   color: #000000;
# }
# #T_00000_row10_col1 {
#   background-color: #827fbb;
#   color: #f1f1f1;
# }
# #T_00000_row11_col1 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_00000_row12_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_00000_row13_col2 {
#   background-color: #e3c989;
#   color: #000000;
# }
# #T_00000_row13_col3 {
#   background-color: #a09dca;
#   color: #f1f1f1;
# }
# #T_00000_row14_col1 {
#   background-color: #dcdcec;
#   color: #000000;
# }
# </style>
# <table id="T_00000">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00000_level0_col0" class="col_heading level0 col0" colspan="2">X^2</th>
#       <th id="T_00000_level0_col2" class="col_heading level0 col2" colspan="2">p</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >split</th>
#       <th id="T_00000_level1_col0" class="col_heading level1 col0" >alg</th>
#       <th id="T_00000_level1_col1" class="col_heading level1 col1" >tst</th>
#       <th id="T_00000_level1_col2" class="col_heading level1 col2" >alg</th>
#       <th id="T_00000_level1_col3" class="col_heading level1 col3" >tst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >col</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00000_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_00000_row0_col0" class="data row0 col0" >0.084</td>
#       <td id="T_00000_row0_col1" class="data row0 col1" >0.002</td>
#       <td id="T_00000_row0_col2" class="data row0 col2" >100.0</td>
#       <td id="T_00000_row0_col3" class="data row0 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row1" class="row_heading level0 row1" >capital-gain</th>
#       <td id="T_00000_row1_col0" class="data row1 col0" >1.753</td>
#       <td id="T_00000_row1_col1" class="data row1 col1" >0.001</td>
#       <td id="T_00000_row1_col2" class="data row1 col2" >100.0</td>
#       <td id="T_00000_row1_col3" class="data row1 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row2" class="row_heading level0 row2" >capital-loss</th>
#       <td id="T_00000_row2_col0" class="data row2 col0" >0.001</td>
#       <td id="T_00000_row2_col1" class="data row2 col1" >0.001</td>
#       <td id="T_00000_row2_col2" class="data row2 col2" >100.0</td>
#       <td id="T_00000_row2_col3" class="data row2 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_00000_row3_col0" class="data row3 col0" >0.000</td>
#       <td id="T_00000_row3_col1" class="data row3 col1" >0.001</td>
#       <td id="T_00000_row3_col2" class="data row3 col2" >100.0</td>
#       <td id="T_00000_row3_col3" class="data row3 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row4" class="row_heading level0 row4" >education-num</th>
#       <td id="T_00000_row4_col0" class="data row4 col0" >0.000</td>
#       <td id="T_00000_row4_col1" class="data row4 col1" >0.001</td>
#       <td id="T_00000_row4_col2" class="data row4 col2" >100.0</td>
#       <td id="T_00000_row4_col3" class="data row4 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row5" class="row_heading level0 row5" >fnlwgt</th>
#       <td id="T_00000_row5_col0" class="data row5 col0" >0.000</td>
#       <td id="T_00000_row5_col1" class="data row5 col1" >0.002</td>
#       <td id="T_00000_row5_col2" class="data row5 col2" >100.0</td>
#       <td id="T_00000_row5_col3" class="data row5 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row6" class="row_heading level0 row6" >hours-per-week</th>
#       <td id="T_00000_row6_col0" class="data row6 col0" >0.466</td>
#       <td id="T_00000_row6_col1" class="data row6 col1" >0.003</td>
#       <td id="T_00000_row6_col2" class="data row6 col2" >100.0</td>
#       <td id="T_00000_row6_col3" class="data row6 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row7" class="row_heading level0 row7" >income</th>
#       <td id="T_00000_row7_col0" class="data row7 col0" >0.000</td>
#       <td id="T_00000_row7_col1" class="data row7 col1" >0.000</td>
#       <td id="T_00000_row7_col2" class="data row7 col2" >100.0</td>
#       <td id="T_00000_row7_col3" class="data row7 col3" >99.2</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row8" class="row_heading level0 row8" >marital-status</th>
#       <td id="T_00000_row8_col0" class="data row8 col0" >0.000</td>
#       <td id="T_00000_row8_col1" class="data row8 col1" >0.000</td>
#       <td id="T_00000_row8_col2" class="data row8 col2" >100.0</td>
#       <td id="T_00000_row8_col3" class="data row8 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row9" class="row_heading level0 row9" >native-country</th>
#       <td id="T_00000_row9_col0" class="data row9 col0" >0.001</td>
#       <td id="T_00000_row9_col1" class="data row9 col1" >0.004</td>
#       <td id="T_00000_row9_col2" class="data row9 col2" >100.0</td>
#       <td id="T_00000_row9_col3" class="data row9 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row10" class="row_heading level0 row10" >occupation</th>
#       <td id="T_00000_row10_col0" class="data row10 col0" >0.000</td>
#       <td id="T_00000_row10_col1" class="data row10 col1" >0.002</td>
#       <td id="T_00000_row10_col2" class="data row10 col2" >100.0</td>
#       <td id="T_00000_row10_col3" class="data row10 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row11" class="row_heading level0 row11" >race</th>
#       <td id="T_00000_row11_col0" class="data row11 col0" >0.000</td>
#       <td id="T_00000_row11_col1" class="data row11 col1" >0.000</td>
#       <td id="T_00000_row11_col2" class="data row11 col2" >100.0</td>
#       <td id="T_00000_row11_col3" class="data row11 col3" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_00000_level0_row12" class="row_heading level0 row12" >relationship</th>
#       <td id="T_00000_row12_col0" class="data row12 col0" >0.000</td>
#       <td id="T_00000_row12_col1" class="data row12 col1" >0.000</td>
#       <td id="T_00000_row12_col2" class="data r
