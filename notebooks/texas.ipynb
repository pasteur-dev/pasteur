# %%
from pasteur.kedro.ipython import * # type: ignore
register_kedro() # type: ignore
# Out:
# INFO     Kedro project Pasteur                                                                                           __init__.py:77
# INFO     Defined global variable 'context', 'session', 'catalog' and 'pipelines'                                         __init__.py:78
# INFO     Registered line magic 'run_viz'                                                                                 __init__.py:84

# %%
table = catalog.load("texas.raw@base")["2009q1"]()

# %%
table.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>discharge_qtr</th>
#       <th>thcic_id</th>
#       <th>provider_name</th>
#       <th>fac_teaching_ind</th>
#       <th>fac_psych_ind</th>
#       <th>fac_rehab_ind</th>
#       <th>fac_acute_care_ind</th>
#       <th>fac_snf_ind</th>
#       <th>fac_long_term_ac_ind</th>
#       <th>fac_other_ltc_ind</th>
#       <th>...</th>
#       <th>value_amount_12</th>
#       <th>hcfa_mdc</th>
#       <th>apr_mdc</th>
#       <th>hcfa_drg</th>
#       <th>apr_drg</th>
#       <th>risk_mortality</th>
#       <th>illness_severity</th>
#       <th>attending_phys_unif_id</th>
#       <th>operating_phys_unif_id</th>
# ...

# %%
print("names:")
for k in table.keys():
    print (f"  - {k.lower()}")

print("dtype:")
for k in table.keys():
    print (f"  {k.lower()}: category")
# Out:
# names:
#   - discharge_qtr
#   - thcic_id
#   - provider_name
#   - fac_teaching_ind
#   - fac_psych_ind
#   - fac_rehab_ind
#   - fac_acute_care_ind
#   - fac_snf_ind
#   - fac_long_term_ac_ind
#   - fac_other_ltc_ind
#   - fac_peds_ind
#   - spec_unit
#   - encounter_indicator
#   - sex_code
#   - type_of_admission
#   - source_of_admission
#   - pat_state
#   - pat_zip
#   - pat_country
#   - county
#   - public_health_region
#   - admit_weekday
#   - length_of_stay
#   - pat_age
#   - pat_status
#   - race
#   - ethnicity
#   - first_payment_src
#   - secondary_payment_src
#   - type_of_bill
#   - private_amount
#   - semi_private_amount
#   - ward_amount
#   - ice_amount
#   - ccu_amount
#   - other_amount
#   - pharm_amount
#   - medsurg_amount
#   - dme_amount
#   - used_dme_amount
#   - pt_amount
#   - ot_amount
#   - speech_amount
#   - it_amount
#   - blood_amount
#   - blood_adm_amount
#   - or_amount
#   - lith_amount
#   - card_amount
#   - anes_amount
#   - lab_amount
# ...

# %%
table.info(max_cols=1000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 737678 entries, 120090000509 to 120090632165
# Data columns (total 254 columns):
#  #    Column                        Non-Null Count   Dtype
# ---   ------                        --------------   -----
#  0    discharge_qtr                 737678 non-null  category
#  1    thcic_id                      737678 non-null  int32
#  2    provider_name                 737629 non-null  category
#  3    fac_teaching_ind              170681 non-null  category
#  4    fac_psych_ind                 176444 non-null  category
#  5    fac_rehab_ind                 213901 non-null  category
#  6    fac_acute_care_ind            667359 non-null  category
#  7    fac_snf_ind                   181675 non-null  category
#  8    fac_long_term_ac_ind          15275 non-null   category
#  9    fac_other_ltc_ind             6407 non-null    category
#  10   fac_peds_ind                  251604 non-null  category
# ...

# %%
for name, num in table.nunique().to_dict().items():
    if num > 10000:
        print(f"{name}: {num}")
# Out:
# private_amount: 10208
# semi_private_amount: 17642
# ice_amount: 16167
# other_amount: 30186
# pharm_amount: 313089
# medsurg_amount: 204191
# pt_amount: 31848
# ot_amount: 20136
# it_amount: 70494
# blood_adm_amount: 16573
# or_amount: 75901
# card_amount: 34376
# anes_amount: 19031
# lab_amount: 215627
# rad_amount: 97070
# er_amount: 21613
# total_charges: 531093
# total_non_cov_charges: 16115
# total_charges_accomm: 47183
# total_charges_ancil: 509154
# total_non_cov_charges_ancil: 14510
# value_amount_1: 11250
# value_amount_2: 74373
# value_amount_3: 32815
# attending_phys_unif_id: 18551
# operating_phys_unif_id: 20368
