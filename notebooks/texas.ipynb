# %%
from pasteur.kedro.ipython import * # type: ignore
register_kedro() # type: ignore
# Out:
# INFO     Kedro project Pasteur                                                                                           __init__.py:77
# INFO     Defined global variable 'context', 'session', 'catalog' and 'pipelines'                                         __init__.py:78
# INFO     Registered line magic 'run_viz'                                                                                 __init__.py:84

# %%
base = catalog.load("texas.raw@base")
base1 = catalog.load("texas.raw@base1")
base1_v2 = catalog.load("texas.raw@base1_v2")
base2 = catalog.load("texas.raw@base2")
base1_tst = catalog.load("texas.raw@base1_tst")

# %%
list(base1_v2["2016q4"]().keys())
# Out:
# [
#     'discharge',
#     'thcic_id',
#     'type_of_admission',
#     'source_of_admission',
#     'spec_unit_1',
#     'spec_unit_2',
#     'spec_unit_3',
#     'spec_unit_4',
#     'spec_unit_5',
#     'pat_state',
#     'pat_zip',
#     'pat_country',
#     'pat_county',
#     'public_health_region',
#     'pat_status',
#     'sex_code',
#     'race',
#     'ethnicity',
#     'admit_weekday',
#     'length_of_stay',
#     'pat_age',
#     'first_payment_src',
#     'secondary_payment_src',
#     'type_of_bill',
#     'total_charges',
#     'total_non_cov_charges',
#     'total_charges_accomm',
#     'total_non_cov_charges_accomm',
#     'total_charges_ancil',
#     'total_non_cov_charges_ancil',
#     'admitting_diagnosis',
#     'princ_diag_code',
#     'poa_princ_diag_code',
#     'oth_diag_code_1',
#     'poa_oth_diag_code_1',
#     'oth_diag_code_2',
#     'poa_oth_diag_code_2',
#     'oth_diag_code_3',
#     'poa_oth_diag_code_3',
#     'oth_diag_code_4',
#     'poa_oth_diag_code_4',
#     'oth_diag_code_5',
#     'poa_oth_diag_code_5',
#     'oth_diag_code_6',
#     'poa_oth_diag_code_6',
#     'oth_diag_code_7',
#     'poa_oth_diag_code_7',
#     'oth_diag_code_8',
#     'poa_oth_diag_code_8',
#     'oth_diag_code_9',
#     'poa_oth_diag_code_9',
#     'oth_diag_code_10',
#     'poa_oth_diag_code_10',
#     'oth_diag_code_11',
#     'poa_oth_diag_code_11',
#     'oth_diag_code_12',
#     'poa_oth_diag_code_12',
#     'oth_diag_code_13',
#     'poa_oth_diag_code_13',
#     'oth_diag_code_14',
#     'poa_oth_diag_code_14',
#     'oth_diag_code_15',
#     'poa_oth_diag_code_15',
#     'oth_diag_code_16',
#     'poa_oth_diag_code_16',
#     'oth_diag_code_17',
#     'poa_oth_diag_code_17',
#     'oth_diag_code_18',
#     'poa_oth_diag_code_18',
#     'oth_diag_code_19',
#     'poa_oth_diag_code_19',
#     'oth_diag_code_20',
#     'poa_oth_diag_code_20',
#     'oth_diag_code_21',
#     'poa_oth_diag_code_21',
#     'oth_diag_code_22',
#     'poa_oth_diag_code_22',
#     'oth_diag_code_23',
#     'poa_oth_diag_code_23',
#     'oth_diag_code_24',
#     'poa_oth_diag_code_24',
#     'e_code_1',
#     'poa_e_code_1',
#     'e_code_2',
#     'poa_e_code_2',
#     'e_code_3',
#     'poa_e_code_3',
#     'e_code_4',
#     'poa_e_code_4',
#     'e_code_5',
#     'poa_e_code_5',
#     'e_code_6',
#     'poa_e_code_6',
#     'e_code_7',
#     'poa_e_code_7',
#     'e_code_8',
#     'poa_e_code_8',
#     'e_code_9',
#     'poa_e_code_9',
#     'e_code_10',
#     'poa_e_code_10',
#     'princ_surg_proc_code',
#     'princ_surg_proc_day',
#     'oth_surg_proc_code_1',
#     'oth_surg_proc_day_1',
#     'oth_surg_proc_code_2',
#     'oth_surg_proc_day_2',
#     'oth_surg_proc_code_3',
#     'oth_surg_proc_day_3',
#     'oth_surg_proc_code_4',
#     'oth_surg_proc_day_4',
#     'oth_surg_proc_code_5',
#     'oth_surg_proc_day_5',
#     'oth_surg_proc_code_6',
#     'oth_surg_proc_day_6',
#     'oth_surg_proc_code_7',
#     'oth_surg_proc_day_7',
#     'oth_surg_proc_code_8',
#     'oth_surg_proc_day_8',
#     'oth_surg_proc_code_9',
#     'oth_surg_proc_day_9',
#     'oth_surg_proc_code_10',
#     'oth_surg_proc_day_10',
#     'oth_surg_proc_code_11',
#     'oth_surg_proc_day_11',
#     'oth_surg_proc_code_12',
#     'oth_surg_proc_day_12',
#     'oth_surg_proc_code_13',
#     'oth_surg_proc_day_13',
#     'oth_surg_proc_code_14',
#     'oth_surg_proc_day_14',
#     'oth_surg_proc_code_15',
#     'oth_surg_proc_day_15',
#     'oth_surg_proc_code_16',
#     'oth_surg_proc_day_16',
#     'oth_surg_proc_code_17',
#     'oth_surg_proc_day_17',
#     'oth_surg_proc_code_18',
#     'oth_surg_proc_day_18',
#     'oth_surg_proc_code_19',
#     'oth_surg_proc_day_19',
#     'oth_surg_proc_code_20',
#     'oth_surg_proc_day_20',
#     'oth_surg_proc_code_21',
#     'oth_surg_proc_day_21',
#     'oth_surg_proc_code_22',
#     'oth_surg_proc_day_22',
#     'oth_surg_proc_code_23',
#     'oth_surg_proc_day_23',
#     'oth_surg_proc_code_24',
#     'oth_surg_proc_day_24',
#     'ms_mdc',
#     'ms_drg',
#     'ms_grouper_version_nbr',
#     'ms_grouper_error_code',
#     'apr_mdc',
#     'apr_drg',
#     'risk_mortality',
#     'illness_severity',
#     'apr_grouper_version_nbr',
#     'apr_grouper_error_code',
#     'attending_physician_unif_id',
#     'operating_physician_unif_id',
#     'encounter_indicator',
#     'provider_name',
#     'filler_space'
# ]

# %%
list(base1["2016q4"]())

# %%
base_tmp = base["2006q1"]()

# %%
base1_tmp = base1["2016q4"]()
# base2_tmp = base2["2015q4"]()

# %%
import pandas as pd

spec_unit = base_tmp["spec_unit"].astype(str)

get_spec_idx = lambda i: spec_unit.str.slice(i, i + 1).replace("", pd.NA).astype("category")
spec_units = pd.DataFrame({f"spec_unit_{i + 1}": get_spec_idx(i) for i in range(5)})

# %%
base_itrm = base_tmp.drop(columns=[
    'fac_acute_care_ind',
    'fac_long_term_ac_ind',
    'fac_other_ltc_ind',
    'fac_peds_ind',
    'fac_psych_ind',
    'fac_rehab_ind',
    'fac_snf_ind',
    'fac_teaching_ind',
    "spec_unit"
]).join(spec_units)

# %%
base_new_itrm = base1_tmp.drop(
    columns=[
        "filler_space",
        "apr_grouper_error_code",
        "apr_grouper_version_nbr",
        "ms_grouper_error_code",
        "ms_grouper_version_nbr",
    ]
).join(base2_tmp.drop(columns=["filler_space"]))

# %%
base_keys = set(base_itrm.keys()) 
base_new_keys = set(base_new_itrm)

# %%
sorted(base_new_keys - base_keys)

# %%
pd.concat([base_new_itrm.head(), base_itrm.head()])

# %%
base_loaded = {key: load() for i, (key, load) in enumerate(base.items()) if i < 7}

# %%
dfs = {}

# Load old format base files
for key, tmp in base_loaded.items():
    print(f"Processing {key}...")
    # tmp = load()

    # Generate spec unit in new format
    spec_unit = tmp["spec_unit"].astype(str)
    get_spec_idx = (
        lambda i: spec_unit.str.slice(i, i + 1).replace("", pd.NA).astype("category")
    )
    spec_units = pd.DataFrame({f"spec_unit_{i + 1}": get_spec_idx(i) for i in range(5)})

    # Generate intermediary table
    # new base files now have normalized facility files, so drop denormalized
    # facility columns, as well as old `spec_unit`
    itrm = tmp.drop(
        columns=[
            "fac_acute_care_ind",
            "fac_long_term_ac_ind",
            "fac_other_ltc_ind",
            "fac_peds_ind",
            "fac_psych_ind",
            "fac_rehab_ind",
            "fac_snf_ind",
            "fac_teaching_ind",
            "spec_unit",
        ]
    ).join(spec_units)

    dfs[key] = itrm

dfs_old = dfs

# %%
a = pd.concat(list(dfs_old.values()), copy=False)

# %%
# del a
del dfs
del dfs_old

# %%
# for k in list(globals().keys()):
#     if k.startswith("_i"):
#         del globals()[k]

# import gc
# gc.collect()

# %%
k1 = list(base1_tst["2016q4"]().keys())
k2 = list(base1_tst["2012q4"]().keys())

# %%
for k in k1:
    print(f"- {k.lower()}")
# Out:
# - record_id
# - discharge
# - thcic_id
# - type_of_admission
# - source_of_admission
# - spec_unit_1
# - spec_unit_2
# - spec_unit_3
# - spec_unit_4
# - spec_unit_5
# - pat_state
# - pat_zip
# - pat_country
# - pat_county
# - public_health_region
# - pat_status
# - sex_code
# - race
# - ethnicity
# - admit_weekday
# - length_of_stay
# - pat_age
# - first_payment_src
# - secondary_payment_src
# - type_of_bill
# - total_charges
# - total_non_cov_charges
# - total_charges_accomm
# - total_non_cov_charges_accomm
# - total_charges_ancil
# - total_non_cov_charges_ancil
# - admitting_diagnosis
# - princ_diag_code
# - poa_princ_diag_code
# - oth_diag_code_1
# - poa_oth_diag_code_1
# - oth_diag_code_2
# - poa_oth_diag_code_2
# - oth_diag_code_3
# - poa_oth_diag_code_3
# - oth_diag_code_4
# - poa_oth_diag_code_4
# - oth_diag_code_5
# - poa_oth_diag_code_5
# - oth_diag_code_6
# - poa_oth_diag_code_6
# - oth_diag_code_7
# - poa_oth_diag_code_7
# - oth_diag_code_8
# - poa_oth_diag_code_8
# - oth_diag_code_9
# - poa_oth_diag_code_9
# - oth_diag_code_10
# - poa_oth_diag_code_10
# - oth_diag_code_11
# - poa_oth_diag_code_11
# - oth_diag_code_12
# - poa_oth_diag_code_12
# - oth_diag_code_13
# - poa_oth_diag_code_13
# - oth_diag_code_14
# - poa_oth_diag_code_14
# - oth_diag_code_15
# - poa_oth_diag_code_15
# - oth_diag_code_16
# - poa_oth_diag_code_16
# - oth_diag_code_17
# - poa_oth_diag_code_17
# - oth_diag_code_18
# - poa_oth_diag_code_18
# - oth_diag_code_19
# - poa_oth_diag_code_19
# - oth_diag_code_20
# - poa_oth_diag_code_20
# - oth_diag_code_21
# - poa_oth_diag_code_21
# - oth_diag_code_22
# - poa_oth_diag_code_22
# - oth_diag_code_23
# - poa_oth_diag_code_23
# - oth_diag_code_24
# - poa_oth_diag_code_24
# - e_code_1
# - poa_e_code_1
# - e_code_2
# - poa_e_code_2
# - e_code_3
# - poa_e_code_3
# - e_code_4
# - poa_e_code_4
# - e_code_5
# - poa_e_code_5
# - e_code_6
# - poa_e_code_6
# - e_code_7
# - poa_e_code_7
# - e_code_8
# - poa_e_code_8
# - e_code_9
# - poa_e_code_9
# - e_code_10
# - poa_e_code_10
# - princ_surg_proc_code
# - princ_surg_proc_day
# - oth_surg_proc_code_1
# - oth_surg_proc_day_1
# - oth_surg_proc_code_2
# - oth_surg_proc_day_2
# - oth_surg_proc_code_3
# - oth_surg_proc_day_3
# - oth_surg_proc_code_4
# - oth_surg_proc_day_4
# - oth_surg_proc_code_5
# - oth_surg_proc_day_5
# - oth_surg_proc_code_6
# - oth_surg_proc_day_6
# - oth_surg_proc_code_7
# - oth_surg_proc_day_7
# - oth_surg_proc_code_8
# - oth_surg_proc_day_8
# - oth_surg_proc_code_9
# - oth_surg_proc_day_9
# - oth_surg_proc_code_10
# - oth_surg_proc_day_10
# - oth_surg_proc_code_11
# - oth_surg_proc_day_11
# - oth_surg_proc_code_12
# - oth_surg_proc_day_12
# - oth_surg_proc_code_13
# - oth_surg_proc_day_13
# - oth_surg_proc_code_14
# - oth_surg_proc_day_14
# - oth_surg_proc_code_15
# - oth_surg_proc_day_15
# - oth_surg_proc_code_16
# - oth_surg_proc_day_16
# - oth_surg_proc_code_17
# - oth_surg_proc_day_17
# - oth_surg_proc_code_18
# - oth_surg_proc_day_18
# - oth_surg_proc_code_19
# - oth_surg_proc_day_19
# - oth_surg_proc_code_20
# - oth_surg_proc_day_20
# - oth_surg_proc_code_21
# - oth_surg_proc_day_21
# - oth_surg_proc_code_22
# - oth_surg_proc_day_22
# - oth_surg_proc_code_23
# - oth_surg_proc_day_23
# - oth_surg_proc_code_24
# - oth_surg_proc_day_24
# - ms_mdc
# - ms_drg
# - ms_grouper_version_nbr
# - ms_grouper_error_code
# - apr_mdc
# - apr_drg
# - risk_mortality
# - illness_severity
# - apr_grouper_version_nbr
# - apr_grouper_error_code
# - attending_physician_unif_id
# - operating_physician_unif_id
# - encounter_indicator
# - provider_name
# - unnamed: 166

# %%
print(k1)

# %%
sorted(set(k2) - set(k1))

# %%
sorted(set(k1) - set(k2))

# %%
for n1, n2 in zip(k1, k2):
    print(n1 + " " + n2)
# Out:
# RECORD_ID RECORD_ID
# DISCHARGE DISCHARGE
# THCIC_ID THCIC_ID
# TYPE_OF_ADMISSION PROVIDER_NAME
# SOURCE_OF_ADMISSION TYPE_OF_ADMISSION
# SPEC_UNIT_1 SOURCE_OF_ADMISSION
# SPEC_UNIT_2 SPEC_UNIT_1
# SPEC_UNIT_3 SPEC_UNIT_2
# SPEC_UNIT_4 SPEC_UNIT_3
# SPEC_UNIT_5 SPEC_UNIT_4
# PAT_STATE SPEC_UNIT_5
# PAT_ZIP PAT_STATE
# PAT_COUNTRY PAT_ZIP
# PAT_COUNTY PAT_COUNTRY
# PUBLIC_HEALTH_REGION COUNTY
# PAT_STATUS PUBLIC_HEALTH_REGION
# SEX_CODE PAT_STATUS
# RACE SEX_CODE
# ETHNICITY RACE
# ADMIT_WEEKDAY ETHNICITY
# LENGTH_OF_STAY ADMIT_WEEKDAY
# PAT_AGE LENGTH_OF_STAY
# FIRST_PAYMENT_SRC PAT_AGE
# SECONDARY_PAYMENT_SRC FIRST_PAYMENT_SRC
# TYPE_OF_BILL SECONDARY_PAYMENT_SRC
# TOTAL_CHARGES TYPE_OF_BILL
# TOTAL_NON_COV_CHARGES TOTAL_CHARGES
# TOTAL_CHARGES_ACCOMM TOTAL_NON_COV_CHARGES
# TOTAL_NON_COV_CHARGES_ACCOMM TOTAL_CHARGES_ACCOMM
# TOTAL_CHARGES_ANCIL TOTAL_NON_COV_CHARGES_ACCOMM
# TOTAL_NON_COV_CHARGES_ANCIL TOTAL_CHARGES_ANCIL
# ADMITTING_DIAGNOSIS TOTAL_NON_COV_CHARGES_ANCIL
# PRINC_DIAG_CODE POA_PROVIDER_INDICATOR
# POA_PRINC_DIAG_CODE ADMITTING_DIAGNOSIS
# OTH_DIAG_CODE_1 PRINC_DIAG_CODE
# POA_OTH_DIAG_CODE_1 POA_PRINC_DIAG_CODE
# OTH_DIAG_CODE_2 OTH_DIAG_CODE_1
# POA_OTH_DIAG_CODE_2 POA_OTH_DIAG_CODE_1
# OTH_DIAG_CODE_3 OTH_DIAG_CODE_2
# POA_OTH_DIAG_CODE_3 POA_OTH_DIAG_CODE_2
# OTH_DIAG_CODE_4 OTH_DIAG_CODE_3
# POA_OTH_DIAG_CODE_4 POA_OTH_DIAG_CODE_3
# OTH_DIAG_CODE_5 OTH_DIAG_CODE_4
# POA_OTH_DIAG_CODE_5 POA_OTH_DIAG_CODE_4
# OTH_DIAG_CODE_6 OTH_DIAG_CODE_5
# POA_OTH_DIAG_CODE_6 POA_OTH_DIAG_CODE_5
# OTH_DIAG_CODE_7 OTH_DIAG_CODE_6
# POA_OTH_DIAG_CODE_7 POA_OTH_DIAG_CODE_6
# OTH_DIAG_CODE_8 OTH_DIAG_CODE_7
# POA_OTH_DIAG_CODE_8 POA_OTH_DIAG_CODE_7
# OTH_DIAG_CODE_9 OTH_DIAG_CODE_8
# POA_OTH_DIAG_CODE_9 POA_OTH_DIAG_CODE_8
# OTH_DIAG_CODE_10 OTH_DIAG_CODE_9
# POA_OTH_DIAG_CODE_10 POA_OTH_DIAG_CODE_9
# OTH_DIAG_CODE_11 OTH_DIAG_CODE_10
# POA_OTH_DIAG_CODE_11 POA_OTH_DIAG_CODE_10
# OTH_DIAG_CODE_12 OTH_DIAG_CODE_11
# POA_OTH_DIAG_CODE_12 POA_OTH_DIAG_CODE_11
# OTH_DIAG_CODE_13 OTH_DIAG_CODE_12
# POA_OTH_DIAG_CODE_13 POA_OTH_DIAG_CODE_12
# OTH_DIAG_CODE_14 OTH_DIAG_CODE_13
# POA_OTH_DIAG_CODE_14 POA_OTH_DIAG_CODE_13
# OTH_DIAG_CODE_15 OTH_DIAG_CODE_14
# POA_OTH_DIAG_CODE_15 POA_OTH_DIAG_CODE_14
# OTH_DIAG_CODE_16 OTH_DIAG_CODE_15
# POA_OTH_DIAG_CODE_16 POA_OTH_DIAG_CODE_15
# OTH_DIAG_CODE_17 OTH_DIAG_CODE_16
# POA_OTH_DIAG_CODE_17 POA_OTH_DIAG_CODE_16
# OTH_DIAG_CODE_18 OTH_DIAG_CODE_17
# POA_OTH_DIAG_CODE_18 POA_OTH_DIAG_CODE_17
# OTH_DIAG_CODE_19 OTH_DIAG_CODE_18
# POA_OTH_DIAG_CODE_19 POA_OTH_DIAG_CODE_18
# OTH_DIAG_CODE_20 OTH_DIAG_CODE_19
# POA_OTH_DIAG_CODE_20 POA_OTH_DIAG_CODE_19
# OTH_DIAG_CODE_21 OTH_DIAG_CODE_20
# POA_OTH_DIAG_CODE_21 POA_OTH_DIAG_CODE_20
# OTH_DIAG_CODE_22 OTH_DIAG_CODE_21
# POA_OTH_DIAG_CODE_22 POA_OTH_DIAG_CODE_21
# OTH_DIAG_CODE_23 OTH_DIAG_CODE_22
# POA_OTH_DIAG_CODE_23 POA_OTH_DIAG_CODE_22
# OTH_DIAG_CODE_24 OTH_DIAG_CODE_23
# POA_OTH_DIAG_CODE_24 POA_OTH_DIAG_CODE_23
# E_CODE_1 OTH_DIAG_CODE_24
# POA_E_CODE_1 POA_OTH_DIAG_CODE_24
# E_CODE_2 E_CODE_1
# POA_E_CODE_2 POA_E_CODE_1
# E_CODE_3 E_CODE_2
# POA_E_CODE_3 POA_E_CODE_2
# E_CODE_4 E_CODE_3
# POA_E_CODE_4 POA_E_CODE_3
# E_CODE_5 E_CODE_4
# POA_E_CODE_5 POA_E_CODE_4
# E_CODE_6 E_CODE_5
# POA_E_CODE_6 POA_E_CODE_5
# E_CODE_7 E_CODE_6
# POA_E_CODE_7 POA_E_CODE_6
# E_CODE_8 E_CODE_7
# POA_E_CODE_8 POA_E_CODE_7
# E_CODE_9 E_CODE_8
# POA_E_CODE_9 POA_E_CODE_8
# E_CODE_10 E_CODE_9
# POA_E_CODE_10 POA_E_CODE_9
# PRINC_SURG_PROC_CODE E_CODE_10
# PRINC_SURG_PROC_DAY POA_E_CODE_10
# OTH_SURG_PROC_CODE_1 PRINC_SURG_PROC_CODE
# OTH_SURG_PROC_DAY_1 PRINC_SURG_PROC_DAY
# OTH_SURG_PROC_CODE_2 PRINC_ICD9_CODE
# OTH_SURG_PROC_DAY_2 OTH_SURG_PROC_CODE_1
# OTH_SURG_PROC_CODE_3 OTH_SURG_PROC_DAY_1
# OTH_SURG_PROC_DAY_3 OTH_ICD9_CODE_1
# OTH_SURG_PROC_CODE_4 OTH_SURG_PROC_CODE_2
# OTH_SURG_PROC_DAY_4 OTH_SURG_PROC_DAY_2
# OTH_SURG_PROC_CODE_5 OTH_ICD9_CODE_2
# OTH_SURG_PROC_DAY_5 OTH_SURG_PROC_CODE_3
# OTH_SURG_PROC_CODE_6 OTH_SURG_PROC_DAY_3
# OTH_SURG_PROC_DAY_6 OTH_ICD9_CODE_3
# OTH_SURG_PROC_CODE_7 OTH_SURG_PROC_CODE_4
# OTH_SURG_PROC_DAY_7 OTH_SURG_PROC_DAY_4
# OTH_SURG_PROC_CODE_8 OTH_ICD9_CODE_4
# OTH_SURG_PROC_DAY_8 OTH_SURG_PROC_CODE_5
# OTH_SURG_PROC_CODE_9 OTH_SURG_PROC_DAY_5
# OTH_SURG_PROC_DAY_9 OTH_ICD9_CODE_5
# OTH_SURG_PROC_CODE_10 OTH_SURG_PROC_CODE_6
# OTH_SURG_PROC_DAY_10 OTH_SURG_PROC_DAY_6
# OTH_SURG_PROC_CODE_11 OTH_ICD9_CODE_6
# OTH_SURG_PROC_DAY_11 OTH_SURG_PROC_CODE_7
# OTH_SURG_PROC_CODE_12 OTH_SURG_PROC_DAY_7
# OTH_SURG_PROC_DAY_12 OTH_ICD9_CODE_7
# OTH_SURG_PROC_CODE_13 OTH_SURG_PROC_CODE_8
# OTH_SURG_PROC_DAY_13 OTH_SURG_PROC_DAY_8
# OTH_SURG_PROC_CODE_14 OTH_ICD9_CODE_8
# OTH_SURG_PROC_DAY_14 OTH_SURG_PROC_CODE_9
# OTH_SURG_PROC_CODE_15 OTH_SURG_PROC_DAY_9
# OTH_SURG_PROC_DAY_15 OTH_ICD9_CODE_9
# OTH_SURG_PROC_CODE_16 OTH_SURG_PROC_CODE_10
# OTH_SURG_PROC_DAY_16 OTH_SURG_PROC_DAY_10
# OTH_SURG_PROC_CODE_17 OTH_ICD9_CODE_10
# OTH_SURG_PROC_DAY_17 OTH_SURG_PROC_CODE_11
# OTH_SURG_PROC_CODE_18 OTH_SURG_PROC_DAY_11
# OTH_SURG_PROC_DAY_18 OTH_ICD9_CODE_11
# OTH_SURG_PROC_CODE_19 OTH_SURG_PROC_CODE_12
# OTH_SURG_PROC_DAY_19 OTH_SURG_PROC_DAY_12
# OTH_SURG_PROC_CODE_20 OTH_ICD9_CODE_12
# OTH_SURG_PROC_DAY_20 OTH_SURG_PROC_CODE_13
# OTH_SURG_PROC_CODE_21 OTH_SURG_PROC_DAY_13
# OTH_SURG_PROC_DAY_21 OTH_ICD9_CODE_13
# OTH_SURG_PROC_CODE_22 OTH_SURG_PROC_CODE_14
# OTH_SURG_PROC_DAY_22 OTH_SURG_PROC_DAY_14
# OTH_SURG_PROC_CODE_23 OTH_ICD9_CODE_14
# OTH_SURG_PROC_DAY_23 OTH_SURG_PROC_CODE_15
# OTH_SURG_PROC_CODE_24 OTH_SURG_PROC_DAY_15
# OTH_SURG_PROC_DAY_24 OTH_ICD9_CODE_15
# MS_MDC OTH_SURG_PROC_CODE_16
# MS_DRG OTH_SURG_PROC_DAY_16
# MS_GROUPER_VERSION_NBR OTH_ICD9_CODE_16
# MS_GROUPER_ERROR_CODE OTH_SURG_PROC_CODE_17
# APR_MDC OTH_SURG_PROC_DAY_17
# APR_DRG OTH_ICD9_CODE_17
# RISK_MORTALITY OTH_SURG_PROC_CODE_18
# ILLNESS_SEVERITY OTH_SURG_PROC_DAY_18
# APR_GROUPER_VERSION_NBR OTH_ICD9_CODE_18
# APR_GROUPER_ERROR_CODE OTH_SURG_PROC_CODE_19
# ATTENDING_PHYSICIAN_UNIF_ID OTH_SURG_PROC_DAY_19
# OPERATING_PHYSICIAN_UNIF_ID OTH_ICD9_CODE_19
# ENCOUNTER_INDICATOR OTH_SURG_PROC_CODE_20
# PROVIDER_NAME OTH_SURG_PROC_DAY_20
# Unnamed: 166 OTH_ICD9_CODE_20
